# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("datasets/iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  40 non-null     float64
#  1   sepal_width   40 non-null     float64
#  2   petal_length  40 non-null     float64
#  3   petal_width   40 non-null     float64
#  4   species       40 non-null     object
# dtypes: float64(4), object(1)
# memory usage: 1.7+ KB
#        sepal_length  sepal_width  petal_length  petal_width
# count     40.000000    40.000000     40.000000    40.000000
# mean       5.685000     3.192500      3.252500     0.972500
# std        0.906543     0.468159      1.946198     0.802556
# min        4.300000     2.300000      1.100000     0.100000
# 25%        4.900000     2.900000      1.400000     0.200000
# 50%        5.450000     3.100000      2.500000     0.700000
# 75%        6.425000     3.500000      4.750000     1.625000
# ...

# %%
df.hist(figsize=(10, 6))
plt.suptitle("Distribution of Numerical Features")
plt.show()

# %%
sns.countplot(x="species", data=df)
plt.title("Count of Iris Species")
plt.show()

# %%
sns.boxplot(data=df.drop("species", axis=1))
plt.title("Outlier Detection using Box Plot")
plt.show()

# %%
corr = df.drop("species", axis=1).corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
import pandas as pd

from eda_utils import (
    basic_overview,
    plot_numerical_distributions,
    plot_categorical_counts,
    detect_outliers,
    correlation_heatmap
)

df = pd.read_csv("datasets/iris.csv")
df.head()

OUTPUT_DIR = "outputs_iris"

basic_overview(df)

plot_numerical_distributions(df, OUTPUT_DIR)

plot_categorical_counts(df, "species", OUTPUT_DIR)

detect_outliers(df, OUTPUT_DIR)

correlation_heatmap(df, OUTPUT_DIR)
# Out:
# 🔹 Dataset Shape:
# (40, 5)
#
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  40 non-null     float64
#  1   sepal_width   40 non-null     float64
#  2   petal_length  40 non-null     float64
#  3   petal_width   40 non-null     float64
#  4   species       40 non-null     object
# dtypes: float64(4), object(1)
# memory usage: 1.7+ KB
# None
#
# 🔹 Statistical Summary:
#        sepal_length  sepal_width  petal_length  petal_width
# count     40.000000    40.000000     40.000000    40.000000
# mean       5.685000     3.192500      3.252500     0.972500
# std        0.906543     0.468159      1.946198     0.802556
# min        4.300000     2.300000      1.100000     0.100000
# 25%        4.900000     2.900000      1.400000     0.200000
# 50%        5.450000     3.100000      2.500000     0.700000
# ...
